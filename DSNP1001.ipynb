# %% [markdown]
# # Data Science in Practice - Scraping - 1001
#
# ## Scraping Ascents of Routes.
#
# Author : Eoghan Cunningham

# %%
import pandas as pd
import urllib.request
import numpy as np
import matplotlib.pyplot as plt
import os
import os.path
import re
from bs4 import BeautifulSoup
from datetime import datetime
import scrapy
from loguru import logger
from scrapy.crawler import CrawlerProcess

# %% [markdown]
# Below are the necessary links to access route and climber details respectively. As you can see I've them up so they can be formatted with the route or climber ID and I tested it quickly with my own ID.

# %%
ukc_climbers_dir = '../data/raw/'
route_link = 'https://www.ukclimbing.com/logbook/c.php?i={}'
graphs_link = 'https://www.ukclimbing.com/logbook/showgraph.php?id={}'
crag_link = 'https://www.ukclimbing.com/logbook/crag.php?id={}'
my_climber_id = '220094'
british_grades = ['S','HS','VS','HVS','E1','E2','E3','E4','E5','E6','E7','E8']
graphs_link.format(my_climber_id)
# Out:
# 'https://www.ukclimbing.com/logbook/showgraph.php?id=220094'

# %% [markdown]
# To begin scraping, we define a dict of the crags (locations) at which we wish to consider routes.
# I have collected the IDs used to identify each of the crags we plan to use.

# %%
crags = {
    'fair_head' : '17029',
    'dalkey_quarry' : '2337',
    'dinas_cromlech' : '4',
    'gogarth_south_stack' : '612',
    'gogarth_north_stack' : '598',
    'vivian_quarry' : '639',
    'rainbow_slab' : '637',
    'st_govans_head' : '7',
    'stennis_head' : '429',
    'rhoscolyn': '617',
    'curbar_edge' : '21',
    'millstone_edge' : '19',
    'cloggy': '457',
    'tremadog' : '221'
}

# %% [markdown]
# ## Scraping Routes - get_routes()
#
# The following function is written to take the crag ID and produce a dataframe of all of the relevant ascents at this crag.
#
# ### Filtering :
#
# **Why?**
#
# The function filters many of the routes from each location. It is important that the filtering takes place at this stage in the process to avoid unneccesary scraping later in the data retrieval proccess.
#
# **How?**
#
# Routes that are not considered to have a *significant* number of ascents will not be used. We do not believe we can make solid inferences from routes with less than 100 ascents. Such routes are removed.
#
# Routes with lower grades are far less likely to contain unsuccessful attempts. Such unsuccessful attempts will prove the basis for answering our research questions about grading. Routes with easier grades also contain far more ascents due to their accessibility. As a result scraping such routes will slow down the data retrieval proccess and the resulting data will prove less useful.

# %%
def get_routes(crag_id) : 
    
    # format the crag link to produce the url, request it and use BS to parse the resulting html
    link = crag_link.format(crag_id)
    source = urllib.request.urlopen(link).read()
    soup = BeautifulSoup(source,'html.parser')

    # the name of the crag is stored here 
    location = soup.select('#breadcrumb-container > div > div.nav-tabs-header > h1')[0].text

    # each table row represents a route at the location. 
    table_rows = soup.find_all("tr")
    
    rows = []
    
    # iterate over these rows, skipping the first as it is a header. 
    for tr in table_rows[1:]:
        td = tr.find_all('td')
        info = [tr.text for tr in td] 
        # the route-id and number of ascents are not found in the text and need to be retieved manually.
        info.extend([tr.get("data-id"),tr.nextSibling]) 
        # if the grade for the route is not british, the row may contain 7 values. We pad the rest out with blank values.
        rows.append(info + [''] * (7 - len(info)))


    df = pd.DataFrame(rows[2:], columns=["index", "name", "info", "grade", "route_id", "num_ascents", "extra"])
    
    # the number of ascents is sometimes stored in a messy html tag, we use a regex to clean it
    df['num_ascents'] = df['num_ascents'].apply(lambda x : np.nan if x is None else re.sub(r'<.*?>', r'',str(x)))
    # and then cast it to an int
    df['num_ascents'] = df['num_ascents'].apply(lambda x : int(x) if str(x).isnumeric() else 0)

    # filtering based on the number of ascents. The most popular route on the site has 5,800 ascents. 
    df = df[df['num_ascents']>=100]
    df = df[df['num_ascents']<=6000]

    # we need to drop any grades that are not british. 
    # these are either sport routes or boulder problems and cannot be compared. 
    df['grade'] = df['grade'].apply(lambda string: re.split(r' +', str(string))[1] \
                                    if any(grade in string for grade in british_grades) else np.nan)

    # we drop unneccessary columns and any routes with no grades.
    df = df.drop(['index','info','extra'], axis=1).dropna(subset = ['grade'])

    df['location'] = location
    
    return df

# %% [markdown]
# The following calls the above **get_routes** function for each crag (location) in our crags dictionary, incrementally adding the results to our routes dataframe.

# %%
routes = pd.DataFrame(columns=['name','grade','route_id','num_ascents','location'])

logger.debug('Getting routes from {} crags'.format(len(crags)))

for crag_name, crag_id in crags.items():
    logger.debug('Getting routes from {}'.format(crag_name))
    routes = routes.append(get_routes(crag_id))

routes
# Out:
# 2019-05-10 21:40:11.288 | DEBUG    | __main__:<module>:3 - Getting routes from 14 crags
# 2019-05-10 21:40:11.291 | DEBUG    | __main__:<module>:6 - Getting routes from fair_head
# 2019-05-10 21:40:13.883 | DEBUG    | __main__:<module>:6 - Getting routes from dalkey_quarry
# 2019-05-10 21:40:20.129 | DEBUG    | __main__:<module>:6 - Getting routes from dinas_cromlech
# 2019-05-10 21:40:20.766 | DEBUG    | __main__:<module>:6 - Getting routes from gogarth_south_stack
# 2019-05-10 21:40:21.683 | DEBUG    | __main__:<module>:6 - Getting routes from gogarth_north_stack
# 2019-05-10 21:40:22.591 | DEBUG    | __main__:<module>:6 - Getting routes from vivian_quarry
# 2019-05-10 21:40:23.604 | DEBUG    | __main__:<module>:6 - Getting routes from rainbow_slab
# 2019-05-10 21:40:24.681 | DEBUG    | __main__:<module>:6 - Getting routes from st_govans_head
# 2019-05-10 21:40:30.367 | DEBUG    | __main__:<module>:6 - Getting routes from stennis_head
# 2019-05-10 21:40:34.892 | DEBUG    | __main__:<module>:6 - Getting routes from rhoscolyn
# 2019-05-10 21:40:39.298 | DEBUG    | __main__:<module>:6 - Getting routes from curbar_edge
# 2019-05-10 21:40:43.596 | DEBUG    | __main__:<module>:6 - Getting routes from millstone_edge
# 2019-05-10 21:40:48.947 | DEBUG    | __main__:<module>:6 - Getting routes from cloggy
# 2019-05-10 21:40:49.695 | DEBUG    | __main__:<module>:6 - Getting routes from tremadog
#                                       name grade route_id num_ascents  \
# 110                              Hurricane    E2    36923         119
# 120                               Toby Jug    E1    51520         129
# 124                            Jolly Roger    E3    36926         105
# 172                                Burn Up    E1    36944         169
# 224                       An Bealach Rúnda    E1    38806         146
# 303                              Blind Pew    E2    53347         117
# 305                             Mizen Star    E2    53349         101
# 311                                Equinox    E2    53355         144
# 328                         Hell's Kitchen   HVS    51528         246
# 334                                  Aoife    E2    36938         125
# 336                                 Girona    VS    36937         318
# 338                              Chieftain    VS    51529         228
# 339                              Taoiseach    VS    52856         120
# 382                               Fireball    E1    36935         204
# 383                       Midnight Cruiser    E1    36934         323
# 385                                Marconi    E3    51554         117
# 386                         The Embankment    E2    51555         142
# 387                               Railroad    E1    36933         252
# 398                       Fáth Mo Bhuartha    E1    36932         225
# 399                                    GBH    E3    47322         115
# 400                        The Black Thief    VS    36931         406
# 401                              The Fence    VS    51538         331
# 46                                  Thrust   HVS    42289         186
# 51                       Giant's Staircase     S    42294         131
# 59                      Tower Ridge Direct    E2    42301         110
# 69                                  Helios    VS    42310         115
# 96                                   Grave     S    42332         182
# 97                                Pilaster    VS    42333         157
# 102                              Bushmills    E1    42338         164
# 110                      Charleston Direct    VS    48923         117
# ..                                     ...   ...      ...         ...
# 92                                 Meshach   HVS     2514        1397
# 95   Leg break / Meshach / Blinkers Hybrid    E2   122358         124
# 96                                Shadrach    VS     2515        1620
# 97                            The Brothers    VS    41333         491
# 98              The Brothers Direct Finish    E1    96199         136
# 108                              Nifl-Heim   HVS    35929         264
# 111                                  Venom    E3     2517         136
# 114                               Leg Slip    E1     2518         652
# 115                             First Slip    E1     2519         391
# 128                    Knell for a Jackdaw     S    31061         126
# 131                                Oakover    VS    41580         205
# 134                                Axeover    VS   184281         152
# 144                             Belshazzar   HVS    32201         220
# 146                             Daddy Cool    E2     2521         150
# 151                               Rienetta    HS    31103         248
# 154                                 Merlin    VS     2522         727
# 155                          Merlin Direct   HVS     2523        1783
# 158                              Geireagle    E3     2525         250
# 159                                Y Broga   HVS     2526         365
# 161                                 Oberon     S     2527        1636
# 163                  Oberon Original Start    HS   223491         120
# 186                                 Borneo    VS    63666         132
# 189                            Cynhyrchwyr    VS    64010         135
# 191                                    Rio    HS    63623         376
# 198                                  Chwys    E2     2531         179
# 201                  Sheer Khan Right Hand     S    64244         224
# 203          Smarter Than The Average Bear    VS     2533         205
# 204                                   Yogi    VS     2532        1246
# 205                              Mr Ranger    VS    62810         193
# 208                                    Tro    HS    61698         219
#
#                           location
# 110                      Fair Head
# 120                      Fair Head
# 124                      Fair Head
# 172                      Fair Head
# 224                      Fair Head
# 303                      Fair Head
# 305                      Fair Head
# 311                      Fair Head
# 328                      Fair Head
# 334                      Fair Head
# 336                      Fair Head
# 338                      Fair Head
# 339                      Fair Head
# 382                      Fair Head
# 383                      Fair Head
# 385                      Fair Head
# 386                      Fair Head
# 387                      Fair Head
# 398                      Fair Head
# 399                      Fair Head
# 400                      Fair Head
# 401                      Fair Head
# 46                   Dalkey quarry
# 51                   Dalkey quarry
# 59                   Dalkey quarry
# 69                   Dalkey quarry
# 96                   Dalkey quarry
# 97                   Dalkey quarry
# 102                  Dalkey quarry
# 110                  Dalkey quarry
# ..                             ...
# 92   Craig Bwlch y Moch (Tremadog)
# 95   Craig Bwlch y Moch (Tremadog)
# 96   Craig Bwlch y Moch (Tremadog)
# 97   Craig Bwlch y Moch (Tremadog)
# 98   Craig Bwlch y Moch (Tremadog)
# 108  Craig Bwlch y Moch (Tremadog)
# 111  Craig Bwlch y Moch (Tremadog)
# 114  Craig Bwlch y Moch (Tremadog)
# 115  Craig Bwlch y Moch (Tremadog)
# 128  Craig Bwlch y Moch (Tremadog)
# 131  Craig Bwlch y Moch (Tremadog)
# 134  Craig Bwlch y Moch (Tremadog)
# 144  Craig Bwlch y Moch (Tremadog)
# 146  Craig Bwlch y Moch (Tremadog)
# 151  Craig Bwlch y Moch (Tremadog)
# 154  Craig Bwlch y Moch (Tremadog)
# 155  Craig Bwlch y Moch (Tremadog)
# 158  Craig Bwlch y Moch (Tremadog)
# 159  Craig Bwlch y Moch (Tremadog)
# 161  Craig Bwlch y Moch (Tremadog)
# 163  Craig Bwlch y Moch (Tremadog)
# 186  Craig Bwlch y Moch (Tremadog)
# 189  Craig Bwlch y Moch (Tremadog)
# 191  Craig Bwlch y Moch (Tremadog)
# 198  Craig Bwlch y Moch (Tremadog)
# 201  Craig Bwlch y Moch (Tremadog)
# 203  Craig Bwlch y Moch (Tremadog)
# 204  Craig Bwlch y Moch (Tremadog)
# 205  Craig Bwlch y Moch (Tremadog)
# 208  Craig Bwlch y Moch (Tremadog)
#
# [410 rows x 5 columns]

# %% [markdown]
# We can consider the size of the routes dataframe.

# %%
len(routes)
# Out:
# 410

# %%
routes['num_ascents'].sum()
# Out:
# 174223

# %% [markdown]
# Of the above ascents many will not public and a further subset will not be 'Lead' attempts.

# %% [markdown]
# Next we have a function to produce a *pandas dataframe* listing all the ascents of a route given its ID.

# %%
def get_route_ascents(name, grade, location, route_id) : 

    def correct_dates(date) :
        
        # ascents from this year have no year given ie. they take the form DD/MM
        # we use datetime to give the current year (so this should still work in future)
        if date[-1].isalpha() :
            return date+", "+str(datetime.now().year)
        
        return date
        

    link = route_link.format(route_id)
    source = urllib.request.urlopen(link).read()
    soup = BeautifulSoup(source,'html.parser')
    
    # beautiful soup makes it easy to find the table and store all of it rows
    table = soup.find('div', attrs={'id':'public_logbooks'}).find('table')
    table_rows = table.find_all('tr', attrs={'class':''})
        
    ascents = []
    
    for tr in table_rows:
        td = tr.find_all('td')
        #the climber id is contained in the link to their logbook so we need to store that
        link = tr.find('a').get('href')
        info = [tr.text for tr in td]
        #then we can use a regex to grab it
        climber_id = re.sub(r'.*=', r'', link)
        info.append(climber_id)
        ascents.append(info)
        
        
    # we can convert the ascents data we've just collected into a dataframe
    df = pd.DataFrame(ascents, columns=["name", "date", "style", "comment", "climber_id"])
    
    
    # empty values are represented with a dash, we want to replace these with np.nan
    df['style'] = np.where(df['style']=='-', np.nan, df['style'])
    
    # and drop these null values
    df = df.dropna(subset=['style'])
    
    # finally we can fix the dates
    df['date'] = df["date"].apply(correct_dates)
    
    df['name'] = name
    df['grade'] = grade
    df['location'] = location
    
    return df

# %% [markdown]
# The following function is used to produce a full list of ascents from our routes dataframe by applying the **get_route_ascents** function to each route and collecting the results in a new dataframe.

# %%
def get_ascents(routes) : 
    
    ascents = pd.DataFrame(columns=['name', 'date', 'style', 'comment', 'climber_id', 'grade', 'location'])
    for _, row in routes.iterrows():
        ascents = ascents.append(get_route_ascents(row['name'], row['grade'], row['location'], row['route_id']))

    return ascents

# %%
ascents = get_ascents(routes)
ascents
# Out:
#           name          date      style  \
# 0    Hurricane  20 Apr, 2019    2nd O/S
# 1    Hurricane  20 Apr, 2019   Lead O/S
# 2    Hurricane  15 Oct, 2018   Lead O/S
# 3    Hurricane  27 Jul, 2018       Lead
# 4    Hurricane  19 Jul, 2018   Lead O/S
# 5    Hurricane   7 Jul, 2018  AltLd O/S
# 6    Hurricane  25 Jun, 2018  AltLd O/S
# 7    Hurricane   4 Jun, 2018  AltLd O/S
# 8    Hurricane   3 Jun, 2018      AltLd
# 9    Hurricane   3 Jun, 2018  AltLd O/S
# 10   Hurricane   2 Jun, 2018   Lead O/S
# 11   Hurricane   2 Jun, 2018      AltLd
# 12   Hurricane  10 Jul, 2017  AltLd O/S
# 13   Hurricane  10 Jul, 2017  AltLd O/S
# 14   Hurricane   5 Jun, 2017   Lead dnf
# 15   Hurricane   3 Jun, 2017       Lead
# 16   Hurricane   2 Jun, 2017  AltLd O/S
# 17   Hurricane   2 Jun, 2017  AltLd O/S
# 18   Hurricane   2 Jun, 2017  AltLd O/S
# 19   Hurricane   1 Jun, 2017       Lead
# 20   Hurricane  11 May, 2017   Lead dog
# 21   Hurricane   6 May, 2017       Lead
# 22   Hurricane   6 May, 2017        2nd
# 23   Hurricane    ?May, 2017   Lead O/S
# 24   Hurricane   6 Aug, 2016   Lead O/S
# 25   Hurricane  23 Jul, 2016        2nd
# 26   Hurricane  23 Jul, 2016  AltLd O/S
# 27   Hurricane   3 Jul, 2016    2nd rpt
# 28   Hurricane   3 Jul, 2016   Lead O/S
# 29   Hurricane   4 Jun, 2016  AltLd rpt
# ..         ...           ...        ...
# 111        Tro  31 May, 2010       Lead
# 112        Tro  25 Apr, 2010    2nd O/S
# 113        Tro  25 Apr, 2010   Lead O/S
# 114        Tro  24 Apr, 2010       Lead
# 115        Tro  20 Apr, 2010   Lead O/S
# 116        Tro  22 Feb, 2010       Solo
# 117        Tro  22 Feb, 2010   Solo O/S
# 118        Tro  10 Feb, 2010   Lead O/S
# 119        Tro  10 Feb, 2010        2nd
# 120        Tro   9 Feb, 2010       Lead
# 121        Tro    ?Jan, 2010        2nd
# 122        Tro    ?Jan, 2010        2nd
# 123        Tro      ??, 2010   Lead O/S
# 124        Tro  30 Dec, 2009    2nd rpt
# 125        Tro   4 Oct, 2009    2nd O/S
# 126        Tro   4 Oct, 2009       Lead
# 127        Tro    ?Sep, 2009    2nd O/S
# 128        Tro  19 Aug, 2009   Lead O/S
# 129        Tro  13 Aug, 2009   Lead O/S
# 130        Tro  11 Jul, 2009    2nd O/S
# 131        Tro   2 Jul, 2009    2nd O/S
# 132        Tro  18 Jun, 2009       Lead
# 133        Tro   8 Mar, 2009        2nd
# 134        Tro   8 Mar, 2009   Lead O/S
# 135        Tro  26 Apr, 2008  AltLd O/S
# 136        Tro   4 Oct, 2007     TR rpt
# 137        Tro  24 Mar, 2007       Lead
# 138        Tro  23 Mar, 2007   Lead rpt
# 139        Tro  11 Feb, 2007   Lead O/S
# 140        Tro      ??, 2003   Lead O/S
#
#                                                comment climber_id grade  \
# 0                                          with Flavio     197782    E2
# 1    In one massive victory pitch. Puts all hand ja...     185136    E2
# 2    Another brilliant FH E2. Lead both pitches and...      57132    E2
# 3                                             with Ali      63985    E2
# 4                                       Led both pitch     233566    E2
# 5                                    with Robert Duran     133563    E2
# 6             Great splitter climbing.with Mike Hutton      12933    E2
# 7                            Amazing! Led p2with Aggie     158515    E2
# 8    P2 easy finish. Really good fun.with Paul Collins     186094    E2
# 9                                     Pitch 1with bren     151893    E2
# 10   Nice to finish it off after previously having ...     199444    E2
# 11                        Lead first pitch class route     168347    E2
# 12   P2. Started up direct finish but hard so went ...      35159    E2
# 13                      P1 what a cracker!with Ed Babs      41303    E2
# 14   P1 only then abseiled off in the rainwith paul...     199444    E2
# 15   Made a balls of the crux. Still not great on j...     186094    E2
# 16                                                         213309    E2
# 17    Lead P2. Great teamwork! ðŸ˜with Wendy Watthews     200143    E2
# 18   Brilliant birthday route, I lead P1 and aby p2...     148131    E2
# 19      Excellent, one of my favorite climbs.with Adam     104874    E2
# 20   Led pitch 1. Foot slip on crux sectionwith Nic...     124064    E2
# 21   Nice to come back and do this properly. hard w...     108451    E2
# 22                                         with cjcuni     149776    E2
# 23   One pitch.  Just a really nice route, possibly...     170619    E2
# 24                                          with Anna       94967    E2
# 25                            Still can't jamwith John      54307    E2
# 26   Done direct version recently but this is well ...     187253    E2
# 27                                        with zcsharp     127212    E2
# 28   Lead it in one big pitch while it was raining ...     149776    E2
# 29                          Did the easier first pitch     101126    E2
# ..                                                 ...        ...   ...
# 111  Pleasant enough outing. Low crux, no more than...       3620    HS
# 112                          good to get backwith Mr G     103468    HS
# 113  Still dry-ish after a classic welsh day (raini...      95800    HS
# 114                                          with Paul     108607    HS
# 115                                      with Pencarth      95468    HS
# 116                                      with dan-8990      97432    HS
# 117                                                         93568    HS
# 118                                   with Keith Jones      97156    HS
# 119                                with christoph owen      36465    HS
# 120                        with allysingo, David Jones      36465    HS
# 121                                with andrew hammond      99565    HS
# 122                                with andrew hammond      99565    HS
# 123                                    with jack adams     114652    HS
# 124                                 with Dylan Burgess     103616    HS
# 125                                     with Wyn Price      22562    HS
# 126                                          with Phil      62667    HS
# 127                                                         92533    HS
# 128  Wet climb, Ross jumared alongside to check gea...      99392    HS
# 129                                        with Nathan      87662    HS
# 130  Nice climbing after a tricky first few moves.w...      11336    HS
# 131                                          with Dnmn      65287    HS
# 132                                         with WILLS      72048    HS
# 133                                  with phildavies84      99565    HS
# 134  really good, easyish start but with little gea...      75858    HS
# 135  Relatively poorly protected upper reaches. Tak...      27508    HS
# 136                                                         71539    HS
# 137                          with dilwyn4, David Jones      36465    HS
# 138                                with Alec and Jenny      55358    HS
# 139                                   with Alec Folley      55358    HS
# 140                                                          2442    HS
#
#                           location
# 0                        Fair Head
# 1                        Fair Head
# 2                        Fair Head
# 3                        Fair Head
# 4                        Fair Head
# 5                        Fair Head
# 6                        Fair Head
# 7                        Fair Head
# 8                        Fair Head
# 9                        Fair Head
# 10                       Fair Head
# 11                       Fair Head
# 12                       Fair Head
# 13                       Fair Head
# 14                       Fair Head
# 15                       Fair Head
# 16                       Fair Head
# 17                       Fair Head
# 18                       Fair Head
# 19                       Fair Head
# 20                       Fair Head
# 21                       Fair Head
# 22                       Fair Head
# 23                       Fair Head
# 24                       Fair Head
# 25                       Fair Head
# 26                       Fair Head
# 27                       Fair Head
# 28                       Fair Head
# 29                       Fair Head
# ..                             ...
# 111  Craig Bwlch y Moch (Tremadog)
# 112  Craig Bwlch y Moch (Tremadog)
# 113  Craig Bwlch y Moch (Tremadog)
# 114  Craig Bwlch y Moch (Tremadog)
# 115  Craig Bwlch y Moch (Tremadog)
# 116  Craig Bwlch y Moch (Tremadog)
# 117  Craig Bwlch y Moch (Tremadog)
# 118  Craig Bwlch y Moch (Tremadog)
# 119  Craig Bwlch y Moch (Tremadog)
# 120  Craig Bwlch y Moch (Tremadog)
# 121  Craig Bwlch y Moch (Tremadog)
# 122  Craig Bwlch y Moch (Tremadog)
# 123  Craig Bwlch y Moch (Tremadog)
# 124  Craig Bwlch y Moch (Tremadog)
# 125  Craig Bwlch y Moch (Tremadog)
# 126  Craig Bwlch y Moch (Tremadog)
# 127  Craig Bwlch y Moch (Tremadog)
# 128  Craig Bwlch y Moch (Tremadog)
# 129  Craig Bwlch y Moch (Tremadog)
# 130  Craig Bwlch y Moch (Tremadog)
# 131  Craig Bwlch y Moch (Tremadog)
# 132  Craig Bwlch y Moch (Tremadog)
# 133  Craig Bwlch y Moch (Tremadog)
# 134  Craig Bwlch y Moch (Tremadog)
# 135  Craig Bwlch y Moch (Tremadog)
# 136  Craig Bwlch y Moch (Tremadog)
# 137  Craig Bwlch y Moch (Tremadog)
# 138  Craig Bwlch y Moch (Tremadog)
# 139  Craig Bwlch y Moch (Tremadog)
# 140  Craig Bwlch y Moch (Tremadog)
#
# [121247 rows x 7 columns]

# %%
len(ascents)
# Out:
# 121247

# %% [markdown]
# We can see we've already lost many ascents as our function did not scrape 'hidden' ascents. Such ascents contain minimal data (just the date) and we don't believe anything can be learned from them.
#
# Further, we wish only to consider 'Lead' attempts. In particular we wish to exclude '2nd' or 'Top rope' ascents. In these cases the 2nd climber was essentially brought up the route by the leader. The 2nd climber would have been able to avoid much of the difficulty and danger of the route and thus, the ascent is not valid.

# %%
leads = (ascents['style'].str.contains('Lead ')) | (ascents['style'].str.contains('AltLd '))
lead_ascents = ascents[leads]
len(lead_ascents)
# Out:
# 60243

# %% [markdown]
# Finally we can store the dataset of all of the ascents.

# %%
#lead_ascents.to_csv("../data/ascents_data.csv")
